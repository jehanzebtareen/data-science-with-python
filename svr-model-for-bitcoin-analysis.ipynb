# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('/content/Bitcoin Historical Data yearly.csv')
df.head(7)
# Out:
#    Jun 05, 2022  29,634.30
# 0  Jun 04, 2022  29,864.30
# 1  Jun 03, 2022  29,700.90
# 2  Jun 02, 2022  30,455.50
# 3  Jun 01, 2022  29,798.50
# 4  May 31, 2022  31,793.40
# 5  May 30, 2022  31,723.30
# 6  May 29, 2022  29,465.20

# %%
#Remove the Date column
df.drop(['Date'], 1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
#Show the first 7 rows of the new data set
df.head(7)
# Out:
#        Price
# 0  29,634.30
# 1  29,864.30
# 2  29,700.90
# 3  30,455.50
# 4  29,798.50
# 5  31,793.40
# 6  31,723.30

# %%
#A variable for predicting 'n' days out into the future
prediction_days = 10 #n = 30 days

#Create another column (the target or dependent variable) shifted 'n' units up
df['Prediction'] = df[['Price']].shift(-prediction_days)

# %%
#Show the first 7 rows of the new data set
df.head(7)
# Out:
#        Price Prediction
# 0  29,634.30  29,203.50
# 1  29,864.30  29,540.60
# 2  29,700.90  29,648.70
# 3  30,455.50  29,093.30
# 4  29,798.50  30,286.60
# 5  31,793.40  29,434.60
# 6  31,723.30  29,178.60

# %%
#Show the last 7 rows of the new data set
df.tail(7)
# Out:
#          Price Prediction
# 359  37,314.60        NaN
# 360  36,649.40        NaN
# 361  37,332.20        NaN
# 362  33,382.90        NaN
# 363  33,578.00        NaN
# 364  35,815.40        NaN
# 365  35,520.00        NaN

# %%
#CREATE THE INDEPENDENT DATA SET (X)

# Convert the dataframe to a numpy array and drop the prediction column
X = np.array(df.drop(['Prediction'],1))

#Remove the last 'n' rows where 'n' is the prediction_days
X= X[:len(df)-prediction_days]
print(X)
# Out:
# [['29,634.30']
#  ['29,864.30']
#  ['29,700.90']
#  ['30,455.50']
#  ['29,798.50']
#  ['31,793.40']
#  ['31,723.30']
#  ['29,465.20']
#  ['29,027.10']
#  ['28,601.20']
#  ['29,203.50']
#  ['29,540.60']
#  ['29,648.70']
#  ['29,093.30']
#  ['30,286.60']
#  ['29,434.60']
#  ['29,178.60']
#  ['30,305.90']
#  ['28,683.70']
#  ['30,437.50']
#  ['29,849.00']
#  ['31,308.70']
#  ['30,080.40']
#  ['29,284.40']
#  ['28,976.00']
#  ['29,068.20']
#  ['31,007.50']
#  ['30,095.00']
#  ['34,060.00']
#  ['35,468.00']
#  ['36,009.00']
#  ['36,544.00']
#  ['39,688.00']
#  ['37,718.00']
#  ['38,514.00']
#  ['38,461.00']
#  ['37,650.00']
#  ['38,581.00']
#  ['39,748.00']
#  ['39,243.00']
#  ['38,113.00']
#  ['40,427.00']
#  ['39,464.00']
#  ['39,418.00']
#  ['39,709.00']
#  ['40,482.00']
#  ['41,368.00']
#  ['41,503.00']
#  ['40,803.00']
#  ['39,703.00']
#  ['40,382.00']
#  ['40,560.00']
#  ['39,936.00']
#  ['41,133.00']
#  ['40,078.00']
#  ['39,497.00']
#  ['42,138.00']
#  ['42,767.00']
# ...

# %%
#CREATE THE DEPENDENT DATA SET (y) 
# Convert the dataframe to a numpy array (All of the values including the NaN's)
y = np.array(df['Prediction'])  
# Get all of the y values except the last 'n' rows 
y = y[:-prediction_days] 
print(y)
# Out:
# ['29,203.50' '29,540.60' '29,648.70' '29,093.30' '30,286.60' '29,434.60'
#  '29,178.60' '30,305.90' '28,683.70' '30,437.50' '29,849.00' '31,308.70'
#  '30,080.40' '29,284.40' '28,976.00' '29,068.20' '31,007.50' '30,095.00'
#  '34,060.00' '35,468.00' '36,009.00' '36,544.00' '39,688.00' '37,718.00'
#  '38,514.00' '38,461.00' '37,650.00' '38,581.00' '39,748.00' '39,243.00'
#  '38,113.00' '40,427.00' '39,464.00' '39,418.00' '39,709.00' '40,482.00'
#  '41,368.00' '41,503.00' '40,803.00' '39,703.00' '40,382.00' '40,560.00'
#  '39,936.00' '41,133.00' '40,078.00' '39,497.00' '42,138.00' '42,767.00'
#  '42,275.00' '43,448.00' '43,173.00' '45,506.00' '46,629.00' '46,407.00'
#  '45,811.00' '46,297.00' '45,525.00' '47,075.00' '47,449.00' '47,105.00'
#  '46,859.00' '44,548.00' '44,331.00' '44,013.00' '42,912.00' '42,373.00'
#  '41,022.00' '41,276.00' '42,233.00' '41,767.80' '40,914.80' '41,118.70'
#  '39,285.70' '39,671.10' '37,792.40' '38,814.30' '38,730.20' '39,416.30'
# ...

# %%
# Split the data into 80% training and 20% testing
from sklearn.model_selection import train_test_split
x, x_test, y, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Set prediction_days_array equal to the last 30 rows of the original data set from the price column
prediction_days_array = np.array(df.drop(['Prediction'],1))[-prediction_days:]
print(prediction_days_array)
# Out:
# [['40,529.40']
#  ['39,022.90']
#  ['35,467.50']
#  ['37,314.60']
#  ['36,649.40']
#  ['37,332.20']
#  ['33,382.90']
#  ['33,578.00']
#  ['35,815.40']
#  ['35,520.00']]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
from sklearn.svm import SVR
# Create and train the Support Vector Machine 
svr_linear = SVR(kernel='linear', C=1e2, gamma=0.00000001)#Create the model

# %%
svr_linear.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-ae78767cedbf> in <module>()
# ----> 1 svr_linear.fit(x, y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     194                 order="C",
#     195                 accept_sparse="csr",
# --> 196                 accept_large_sparse=False,
#     197             )
#     198
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
# Testing Model: Score returns the accuracy of the prediction. 
# The best possible score is 1.0
svr_rbf_confidence = svr_rbf.score(x_test, y_test)
print("svr_rbf accuracy: ", svr_rbf_confidence)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-70-e19e78274a2d> in <module>()
#       1 # Testing Model: Score returns the accuracy of the prediction.
#       2 # The best possible score is 1.0
# ----> 3 svr_rbf_confidence = svr_rbf.score(x_test, y_test)
#       4 print("svr_rbf accuracy: ", svr_rbf_confidence)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     703         from .metrics import r2_score
#     704
# --> 705         y_pred = self.predict(X)
#     706         return r2_score(y, y_pred, sample_weight=sample_weight)
#     707
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     412             The predicted values.
#     413         """
# --> 414         X = self._validate_for_predict(X)
# ...
